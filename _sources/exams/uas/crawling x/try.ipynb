# %%
# %pip install twikit asyncio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import asyncio
from twikit import Client

USERNAME = 'ArdiansahN526'
EMAIL = '0cyplh8std@lnovic.com'
PASSWORD = 'halo1234'

# Initialize client
client = Client(language='en-US')

# Di Jupyter Notebook, gunakan await langsung (tidak perlu asyncio.run)
await client.login(
    auth_info_1=USERNAME,
    auth_info_2=EMAIL,
    password=PASSWORD
)

print("✅ Login berhasil!")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In [8], line 12
#       9 client = Client(language='en-US')
#      11 # Di Jupyter Notebook, gunakan await langsung (tidak perlu asyncio.run)
# ---> 12 await client.login(
#      13     auth_info_1=USERNAME,
#      14     auth_info_2=EMAIL,
#      15     password=PASSWORD
#      16 )
#      18 print("✅ Login berhasil!")
#
# File c:\Users\willy\AppData\Local\Programs\Python\Python310\lib\site-packages\twikit\client\client.py:343, in Client.login(self, auth_info_1, auth_info_2, password, totp_secret, cookies_file, enable_ui_metrics)
#     339 guest_token = await self._get_guest_token()
#     341 flow = Flow(self, guest_token)
# --> 343 await flow.execute_task(params={'flow_name': 'login'}, data={
#     344     'input_flow_data': {
#     345         'flow_context': {
#     346             'debug_overrides': {},
# ...
